# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from utils import RecurrentPerceptron

# %%
a = RecurrentPerceptron()

x = np.random.randn(1,10,9)
y = torch.ones(1,10) # all labels one, to visualize training
y = np.array([])
a.train(x, y, lr=0.05, nepochs=100)

# %%
plt.plot([x.item() for x in a.losslog])
plt.show()

# %%
# weights
a.W, a.V
# Out:
# (tensor([ 0.0484, -0.8834,  0.1419,  2.9533,  1.9804, -0.6278,  1.1300, -3.8429,
#           2.2619]),
#  tensor(5.1608))
